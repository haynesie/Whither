# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import numpy as np

# %%
data = pd.read_csv('allconsolelogins.csv')

# %%
hourseries = data['hour']

# %%
xlabels = ['9:00am', '10:00am', '11:00am', '12:00pm', '1:00pm', '2:00pm', '3:00pm', '4:00pm', '5:00pm', '6:00pm', '7:00pm', '8:00pm']

# %%
hourcounts = hourseries.value_counts(sort=False)

# %%
hourcounts.describe()
# Out:
# count    12.00000
# mean     44.25000
# std      26.43388
# min       4.00000
# 25%      23.00000
# 50%      49.00000
# 75%      62.50000
# max      93.00000
# Name: hour, dtype: float64

# %%
plot1 = hourcounts.plot.bar(color='m' ,title="Console Logins by Hour", rot=0, figsize=(11,6))
plot1.set(xlabel='Hour', ylabel='Logins', xticklabels=xlabels)
# Out:
# <img src="data:image/png;base64,..." width="1100">
# [Text(0,0.5,'Logins'),
#  [Text(0,0,'9:00am'),
#   Text(0,0,'10:00am'),
#   Text(0,0,'11:00am'),
#   Text(0,0,'12:00pm'),
#   Text(0,0,'1:00pm'),
#   Text(0,0,'2:00pm'),
#   Text(0,0,'3:00pm'),
#   Text(0,0,'4:00pm'),
#   Text(0,0,'5:00pm'),
#   Text(0,0,'6:00pm'),
#   Text(0,0,'7:00pm'),
#   Text(0,0,'8:00pm')],
#  Text(0.5,0,'Hour')]

# %%
dateseries = data['date']

# %%
datecounts = dateseries.value_counts(sort=False)

# %%
ax= datecounts.plot.bar(color='c', title='Console logins by Date in February', rot=0, figsize=(10,6))
ax.set(xlabel='date', ylabel='number of logins')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# [Text(0,0.5,'number of logins'), Text(0.5,0,'date')]

# %%
import itertools

# %%
columns = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']

# %%
rows = [ 1, 2, 3, 4]

# %%
plt.imshow(LoginsMat, cmap=plt.cm.Greys)

# %%
plt.show()

# %%
def plotMatrix(matrix, col_labels, row_labels, title='Matrix Heatmap', cmap=plt.cm.Greys):
    threshold = matrix.max()/2
    plt.imshow(matrix, cmap)
    plt.title(title)
    plt.colorbar()
    plt.yticks(np.arange(len(row_labels)), row_labels)
    plt.xticks(np.arange(len(col_labels)), col_labels)
    fmt = '.2f'
    for i, j in itertools.product(range(matrix.shape[0]), range(matrix.shape[1])):
        plt.text(j, i, format(matrix[i, j], fmt), horizontalalignment="center", color = "black" \
        if matrix[i,j] < threshold else "white")
    plt.show()

# %%
SysLogins = pd.read_csv('LoginsByMachine.csv')

# %%
SysLogins.describe()
# Out:
#           logins
# count  32.000000
# mean   16.562500
# std    11.575663
# min     0.000000
# 25%     6.000000
# 50%    14.500000
# 75%    23.750000
# max    46.000000

# %%
logins = SysLogins['logins'].get_values()

# %%
loginmatrix = np.matrix(logins.reshape(4,8))

# %%
plotMatrix(loginmatrix, columns, rows, title='Workstation Logins Heatmap', cmap=plt.cm.Blues)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Crashes = pd.read_csv('CrashesByMachine.csv')

# %%
Crashes.describe()
# Out:
#          crashes
# count  32.000000
# mean    1.125000
# std     1.497309
# min     0.000000
# 25%     0.000000
# 50%     0.000000
# 75%     2.000000
# max     5.000000

# %%
crashmatrix = np.matrix(Crashes['crashes'].get_values().reshape(4,8))

# %%
plotMatrix(crashmatrix, columns, rows, title='System Crashes by Machine', cmap=plt.cm.Reds)
# Out:
# <img src="data:image/png;base64,..." width="640">
